# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinwithadash/Melon-Leaf-Prediction-using-Yolov11/blob/main/Kevin_Healthy_Paddy_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.2/887.2 kB 9.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SJs4I0zmErRwcIho6No5")
project = rf.workspace("rice-disease-detection-mwcsk").project("healthy-vs-unhealthy-lbomt")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Healthy-vs-Unhealthy-5 in yolov11:: 100%|██████████| 4576/4576 [00:01<00:00, 2556.08it/s]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
results = model.train(data="/content/Healthy-vs-Unhealthy-5/data.yaml", epochs=10, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 57.0MB/s]
# Ultralytics 8.3.33 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#Displaying image of confusion matrix, prediction, and precision curve
from IPython.display import Image
Image(filename='/content/runs/detect/train/confusion_matrix.png', width=600)
Image(filename='/content/runs/detect/train/val_batch2_pred.jpg', width=600)
Image(filename='/content/runs/detect/train/P_curve.png', width=600)

# %%
import shutil

# Specify the directory where YOLO training outputs are stored
output_dir = "runs/detect/train"  # Update this path if necessary

# Compress the directory
shutil.make_archive("Paddy_Condition_Prediction", "zip", output_dir)

print("YOLO training results have been compressed into 'Paddy_Condition_Prediction'")
# Out:
# YOLO training results have been compressed into 'Paddy_Condition_Prediction'

# %%
from google.colab import files

files.download("Paddy_Condition_Prediction.zip")

# %%
from google.colab import files

# Upload the image from your local machine
uploaded = files.upload()
uploaded_file = list(uploaded.keys())[0]  # Get the name of the uploaded file
print(f"Uploaded file: {uploaded_file}")
# Out:
#      <input type="file" id="files-4d4d27b4-99ea-40f4-acb9-3ecc04e2cdb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d4d27b4-99ea-40f4-acb9-3ecc04e2cdb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# Load the trained YOLO model
model = YOLO("runs/detect/train/weights/best.pt")  # Update the path to your model weights

# %%
from PIL import Image
from IPython.display import Image as IPImage

# Path to the WEBP file
webp_path = "/content/paddy.jpg"

# Convert the WEBP image to PNG
converted_path = "converted_image.png"
image = Image.open(webp_path)
image.save(converted_path, format="PNG")

# Display the PNG image
IPImage(filename=converted_path, width=600)

# %%
# Make predictions on the uploaded image
results = model.predict(source=uploaded_file, save=True)

# Display the first result (as a list of results is returned)
results[0].show()  # This accesses the first result and shows the image with labels

# Optionally, save the results to a file and provide the download link
print(f"Predictions saved in: {results[0].save_dir}")
# Out:
# image 1/1 /content/paddy.jpg: 448x640 1 Healthy, 174.6ms
# Speed: 6.8ms preprocess, 174.6ms inference, 12.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=600x400>
# Predictions saved in: runs/detect/predict
