# %% [markdown]
# <a href="https://colab.research.google.com/github/kevinwithadash/Melon-Leaf-Prediction-using-Yolov11/blob/main/Latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 52.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
#the dataset is in Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
zip_path = "/content/drive/MyDrive/MachineVisionMelon/Melon1.zip"

import os
yolo_folder = '/content/yolo_folder'
os.makedirs(yolo_folder, exist_ok=True)


import zipfile

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(yolo_folder)

# %%
from ultralytics import YOLO


# Load a model
model = YOLO("yolo11n.pt")

# Train the model
results = model.train(data="/content/yolo_folder/data.yaml", epochs=10, imgsz=640)
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
#Displaying image of confusion matrix, prediction, and precision curve
from IPython.display import Image
Image(filename='/content/runs/detect/train2/confusion_matrix.png', width=600)
Image(filename='/content/runs/detect/train2/val_batch1_pred.jpg', width=600)
Image(filename='/content/runs/detect/train2/P_curve.png', width=600)

# %%
import shutil

# Specify the directory where YOLO training outputs are stored
output_dir = "runs/detect/train2"  # Update this path if necessary

# Compress the directory
shutil.make_archive("yolo_training_results2", "zip", output_dir)

print("YOLO training results have been compressed into 'yolo_training_results.zip2'")
# Out:
# YOLO training results have been compressed into 'yolo_training_results.zip2'

# %%
from google.colab import files

files.download("yolo_training_results2.zip")

# %%
from google.colab import files

# Upload the image from your local machine
uploaded = files.upload()
uploaded_file = list(uploaded.keys())[0]  # Get the name of the uploaded file
print(f"Uploaded file: {uploaded_file}")
# Out:
#      <input type="file" id="files-fa10e595-e2eb-491d-acb1-23f974ab3afc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa10e595-e2eb-491d-acb1-23f974ab3afc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

# Load the trained YOLO model
model = YOLO("runs/detect/train2/weights/best.pt")  # Update the path to your model weights

# %%
from PIL import Image
from IPython.display import Image as IPImage

# Path to the WEBP file
webp_path = "/content/OIP (1).jpg"

# Convert the WEBP image to PNG
converted_path = "converted_image.png"
image = Image.open(webp_path)
image.save(converted_path, format="PNG")

# Display the PNG image
IPImage(filename=converted_path, width=600)

# %%
# Make predictions on the uploaded image
results = model.predict(source=uploaded_file, save=True)

# Display the first result (as a list of results is returned)
results[0].show()  # This accesses the first result and shows the image with labels

# Optionally, save the results to a file and provide the download link
print(f"Predictions saved in: {results[0].save_dir}")
# Out:
# image 1/1 /content/OIP (1).jpg: 480x640 11 Anthracnoses, 131.2ms
# Speed: 3.7ms preprocess, 131.2ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=474x355>
# Predictions saved in: runs/detect/predict
